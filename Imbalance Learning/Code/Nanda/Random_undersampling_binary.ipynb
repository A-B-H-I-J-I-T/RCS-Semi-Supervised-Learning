# %%
# %pip install pandas
# %pip install matplotlib
# %pip install scikit-learn
# %pip install imbalanced-learn
# %pip install numpy
# Out:
# Requirement already satisfied: pandas in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (2.0.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from pandas) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from pandas) (1.24.4)
# Requirement already satisfied: six>=1.5 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 23.3.1 is available.
# You should consider upgrading via the '/home/studentx/RCS_M1/pyenv_imbalance/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (3.7.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy<2,>=1.20 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: cycler>=0.10 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from matplotlib) (4.45.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from matplotlib) (6.1.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 23.3.1 is available.
# You should consider upgrading via the '/home/studentx/RCS_M1/pyenv_imbalance/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from scikit-learn) (1.24.4)
# Requirement already satisfied: scipy>=1.5.0 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from scikit-learn) (1.10.1)
# WARNING: You are using pip version 22.0.4; however, version 23.3.1 is available.
# You should consider upgrading via the '/home/studentx/RCS_M1/pyenv_imbalance/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: imbalanced-learn in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (0.11.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from imbalanced-learn) (3.2.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: joblib>=1.1.1 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from imbalanced-learn) (1.24.4)
# Requirement already satisfied: scipy>=1.5.0 in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (from imbalanced-learn) (1.10.1)
# WARNING: You are using pip version 22.0.4; however, version 23.3.1 is available.
# You should consider upgrading via the '/home/studentx/RCS_M1/pyenv_imbalance/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages (1.24.4)
# WARNING: You are using pip version 22.0.4; however, version 23.3.1 is available.
# You should consider upgrading via the '/home/studentx/RCS_M1/pyenv_imbalance/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler, EditedNearestNeighbours
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
import numpy as np

# %%
df = pd.read_csv("good_customer.csv")

# %%
# Convert the 'type' column to numerical values using Label Encoding
label_encoder = LabelEncoder()
df["sex"] = label_encoder.fit_transform(df["sex"])
df["education"] = label_encoder.fit_transform(df["education"])
df["product_type"] = label_encoder.fit_transform(df["product_type"])
df["family_status"] = label_encoder.fit_transform(df["family_status"])

# Split the dataset into features and target
X = df.drop("bad_client_target", axis=1)
y = df["bad_client_target"]

# Handle missing values by filling them with the mean of each column
X = X.fillna(X.mean())

# %%
# Model initializations
classifiers = {
    "Decision Tree": DecisionTreeClassifier(),
    "SVM": SVC(),
    "Logistic Regression": LogisticRegression(max_iter=10000),
    "Naive Bayes": GaussianNB(),
}

# Levels of imbalance to be tested
imbalance_levels = [1500, 1200, 900, 600, 300]

# Define the undersampling techniques
# undersamplers = {
#     "Random UnderSampler": RandomUnderSampler(),
#     "Edited Nearest Neighbours": EditedNearestNeighbours(strategy='')
# }

# %%
# ...

# for sampler_name, sampler in undersamplers.items():
#     print(f"\n\nUsing {sampler_name}\n{'-'*50}")
accuracy_results = {name: [] for name in classifiers}

for level in imbalance_levels:
    print(f"\n\nTesting for imbalance level: {level} samples\n{'-'*50}")

    # if sampler_name == "Random UnderSampler":
    strategy = {0: level}
    sampler = RandomUnderSampler(sampling_strategy=strategy)
    X_resampled, y_resampled = sampler.fit_resample(X, y)
    # elif sampler_name == "Edited Nearest Neighbours":
    #     sampler = EditedNearestNeighbours(sampling_strategy=strategy)
    #     X_resampled, y_resampled = sampler.fit_resample(X, y)

    # Split the resampled data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(
        X_resampled, y_resampled, test_size=0.3, random_state=10
    )

    for name, clf in classifiers.items():
        clf.fit(X_train, y_train)
        predictions = clf.predict(X_test)
        accuracy = accuracy_score(y_test, predictions)
        accuracy_results[name].append(accuracy)
        print(f"Accuracy for {name}: {accuracy:.4f}")
        print(
            f"Classification Report for {name}:\n",
            classification_report(y_test, predictions),
        )
        print("-" * 50)

# Plotting the results for each undersampler
plt.figure(figsize=(12, 7))
for name, accuracies in accuracy_results.items():
    plt.plot(imbalance_levels, accuracies, label=name, marker="o")

# plt.title(f"Model Accuracy vs. Imbalance Level ({sampler_name})")
plt.title(f"Model Accuracy vs. Imbalance Level  (Random Under Sampling)")
plt.xlabel("Number of Samples After Undersampling")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Testing for imbalance level: 1500 samples
# --------------------------------------------------
# Accuracy for Decision Tree: 0.8153
# Classification Report for Decision Tree:
#                precision    recall  f1-score   support
#
#            0       0.90      0.89      0.89       446
#            1       0.28      0.32      0.30        63
#
#     accuracy                           0.82       509
#    macro avg       0.59      0.60      0.60       509
# weighted avg       0.83      0.82      0.82       509
#
# --------------------------------------------------
# Accuracy for SVM: 0.8762
# Classification Report for SVM:
#                precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93       446
#            1       0.00      0.00      0.00        63
#
#     accuracy                           0.88       509
#    macro avg       0.44      0.50      0.47       509
# weighted avg       0.77      0.88      0.82       509
#
# --------------------------------------------------
# Accuracy for Logistic Regression: 0.8762
# Classification Report for Logistic Regression:
#                precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93       446
#            1       0.00      0.00      0.00        63
#
#     accuracy                           0.88       509
#    macro avg       0.44      0.50      0.47       509
# weighted avg       0.77      0.88      0.82       509
#
# --------------------------------------------------
# Accuracy for Naive Bayes: 0.8703
# Classification Report for Naive Bayes:
#                precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       446
#            1       0.40      0.10      0.15        63
#
#     accuracy                           0.87       509
#    macro avg       0.64      0.54      0.54       509
# weighted avg       0.82      0.87      0.83       509
#
# --------------------------------------------------
#
#
# Testing for imbalance level: 1200 samples
# --------------------------------------------------
# Accuracy for Decision Tree: 0.7589
# Classification Report for Decision Tree:
#                precision    recall  f1-score   support
#
#            0       0.88      0.83      0.86       359
#            1       0.25      0.33      0.28        60
#
#     accuracy                           0.76       419
#    macro avg       0.56      0.58      0.57       419
# weighted avg       0.79      0.76      0.77       419
#
# --------------------------------------------------
# Accuracy for SVM: 0.8568
# Classification Report for SVM:
#                precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92       359
#            1       0.00      0.00      0.00        60
#
#     accuracy                           0.86       419
#    macro avg       0.43      0.50      0.46       419
# weighted avg       0.73      0.86      0.79       419
#
# --------------------------------------------------
# Accuracy for Logistic Regression: 0.8568
# Classification Report for Logistic Regression:
#                precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92       359
#            1       0.00      0.00      0.00        60
#
#     accuracy                           0.86       419
#    macro avg       0.43      0.50      0.46       419
# weighted avg       0.73      0.86      0.79       419
#
# --------------------------------------------------
# Accuracy for Naive Bayes: 0.8449
# Classification Report for Naive Bayes:
#                precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91       359
#            1       0.44      0.32      0.37        60
#
#     accuracy                           0.84       419
#    macro avg       0.67      0.62      0.64       419
# weighted avg       0.83      0.84      0.83       419
#
# --------------------------------------------------
#
#
# Testing for imbalance level: 900 samples
# --------------------------------------------------
# Accuracy for Decision Tree: 0.6991
# Classification Report for Decision Tree:
#                precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81       262
#            1       0.26      0.25      0.26        67
#
#     accuracy                           0.70       329
#    macro avg       0.53      0.53      0.53       329
# weighted avg       0.70      0.70      0.70       329
#
# --------------------------------------------------
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy for SVM: 0.7964
# Classification Report for SVM:
#                precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89       262
#            1       0.00      0.00      0.00        67
#
#     accuracy                           0.80       329
#    macro avg       0.40      0.50      0.44       329
# weighted avg       0.63      0.80      0.71       329
#
# --------------------------------------------------
# Accuracy for Logistic Regression: 0.7933
# Classification Report for Logistic Regression:
#                precision    recall  f1-score   support
#
#            0       0.80      0.99      0.88       262
#            1       0.33      0.01      0.03        67
#
#     accuracy                           0.79       329
#    macro avg       0.57      0.50      0.46       329
# weighted avg       0.70      0.79      0.71       329
#
# --------------------------------------------------
# Accuracy for Naive Bayes: 0.7508
# Classification Report for Naive Bayes:
#                precision    recall  f1-score   support
#
#            0       0.84      0.85      0.85       262
#            1       0.38      0.34      0.36        67
#
#     accuracy                           0.75       329
#    macro avg       0.61      0.60      0.60       329
# weighted avg       0.74      0.75      0.75       329
#
# --------------------------------------------------
#
#
# Testing for imbalance level: 600 samples
# --------------------------------------------------
# Accuracy for Decision Tree: 0.7322
# Classification Report for Decision Tree:
#                precision    recall  f1-score   support
#
#            0       0.84      0.81      0.83       187
#            1       0.40      0.46      0.43        52
#
#     accuracy                           0.73       239
#    macro avg       0.62      0.63      0.63       239
# weighted avg       0.75      0.73      0.74       239
#
# --------------------------------------------------
# Accuracy for SVM: 0.7824
# Classification Report for SVM:
#                precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88       187
#            1       0.00      0.00      0.00        52
#
#     accuracy                           0.78       239
#    macro avg       0.39      0.50      0.44       239
# weighted avg       0.61      0.78      0.69       239
#
# --------------------------------------------------
# Accuracy for Logistic Regression: 0.7950
# Classification Report for Logistic Regression:
#                precision    recall  f1-score   support
#
#            0       0.80      0.98      0.88       187
#            1       0.64      0.13      0.22        52
#
#     accuracy                           0.79       239
#    macro avg       0.72      0.56      0.55       239
# weighted avg       0.77      0.79      0.74       239
#
# --------------------------------------------------
# Accuracy for Naive Bayes: 0.7029
# Classification Report for Naive Bayes:
#                precision    recall  f1-score   support
#
#            0       0.87      0.73      0.79       187
#            1       0.38      0.60      0.47        52
#
#     accuracy                           0.70       239
#    macro avg       0.62      0.66      0.63       239
# weighted avg       0.76      0.70      0.72       239
#
# --------------------------------------------------
#
#
# Testing for imbalance level: 300 samples
# --------------------------------------------------
# Accuracy for Decision Tree: 0.5503
# Classification Report for Decision Tree:
#                precision    recall  f1-score   support
#
#            0       0.68      0.57      0.62        95
#            1       0.41      0.52      0.46        54
#
#     accuracy                           0.55       149
#    macro avg       0.54      0.54      0.54       149
# weighted avg       0.58      0.55      0.56       149
#
# --------------------------------------------------
# Accuracy for SVM: 0.6376
# Classification Report for SVM:
#                precision    recall  f1-score   support
#
#            0       0.64      1.00      0.78        95
#            1       0.00      0.00      0.00        54
#
#     accuracy                           0.64       149
#    macro avg       0.32      0.50      0.39       149
# weighted avg       0.41      0.64      0.50       149
#
# --------------------------------------------------
# Accuracy for Logistic Regression: 0.6846
# Classification Report for Logistic Regression:
#                precision    recall  f1-score   support
#
#            0       0.76      0.75      0.75        95
#            1       0.56      0.57      0.57        54
#
#     accuracy                           0.68       149
#    macro avg       0.66      0.66      0.66       149
# weighted avg       0.69      0.68      0.69       149
#
# --------------------------------------------------
# Accuracy for Naive Bayes: 0.5906
# Classification Report for Naive Bayes:
#                precision    recall  f1-score   support
#
#            0       0.72      0.58      0.64        95
#            1       0.45      0.61      0.52        54
#
#     accuracy                           0.59       149
#    macro avg       0.59      0.60      0.58       149
# weighted avg       0.63      0.59      0.60       149
#
# --------------------------------------------------
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# ...

# for sampler_name, sampler in undersamplers.items():
#     print(f"\n\nUsing {sampler_name}\n{'-'*50}")
accuracy_results = {name: [] for name in classifiers}
strategies = ["all", "auto", "not minority", "not majority", "majority"]

for strategy in strategies:
    print(f"\n\nTesting for imbalance level: {level} samples\n{'-'*50}")

    sampler = EditedNearestNeighbours(sampling_strategy=strategy)
    X_resampled, y_resampled = sampler.fit_resample(X, y)

    if len(np.unique(y_resampled)) < 2:
        print(f"Skipping strategy '{strategy}' as it results in one class")
        # Append placeholder values for skipped strategies
        for name in accuracy_results:
            accuracy_results[name].append(np.nan)
        continue

    X_train, X_test, y_train, y_test = train_test_split(
        X_resampled, y_resampled, test_size=0.3, random_state=10
    )

    for name, clf in classifiers.items():
        clf.fit(X_train, y_train)
        predictions = clf.predict(X_test)
        accuracy = accuracy_score(y_test, predictions)
        accuracy_results[name].append(accuracy)
        print(f"Accuracy for {name}: {accuracy:.4f}")
        print(
            f"Classification Report for {name}:\n",
            classification_report(y_test, predictions),
        )
        print("-" * 50)

# Plotting the results for each undersampler
plt.figure(figsize=(12, 7))
for name, accuracies in accuracy_results.items():
    plt.plot(strategies, accuracies, label=name, marker="o")

# plt.title(f"Model Accuracy vs. Imbalance Level ({sampler_name})")
plt.title(f"Model Accuracy vs. Imbalance Level  (Edited Nearest Neighbours)")
plt.xlabel("Number of Samples After Undersampling")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Testing for imbalance level: 300 samples
# --------------------------------------------------
# Skipping strategy 'all' as it results in one class
#
#
# Testing for imbalance level: 300 samples
# --------------------------------------------------
# Accuracy for Decision Tree: 0.7682
# Classification Report for Decision Tree:
#                precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86       324
#            1       0.30      0.37      0.33        60
#
#     accuracy                           0.77       384
#    macro avg       0.59      0.60      0.60       384
# weighted avg       0.79      0.77      0.78       384
#
# --------------------------------------------------
# Accuracy for SVM: 0.8438
# Classification Report for SVM:
#                precision    recall  f1-score   support
#
#            0       0.84      1.00      0.92       324
#            1       0.00      0.00      0.00        60
#
#     accuracy                           0.84       384
#    macro avg       0.42      0.50      0.46       384
# weighted avg       0.71      0.84      0.77       384
#
# --------------------------------------------------
# Accuracy for Logistic Regression: 0.8385
# Classification Report for Logistic Regression:
#                precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91       324
#            1       0.33      0.03      0.06        60
#
#     accuracy                           0.84       384
#    macro avg       0.59      0.51      0.49       384
# weighted avg       0.77      0.84      0.78       384
#
# --------------------------------------------------
# Accuracy for Naive Bayes: 0.8099
# Classification Report for Naive Bayes:
#                precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89       324
#            1       0.38      0.33      0.35        60
#
#     accuracy                           0.81       384
#    macro avg       0.63      0.62      0.62       384
# weighted avg       0.80      0.81      0.81       384
#
# --------------------------------------------------
#
#
# Testing for imbalance level: 300 samples
# --------------------------------------------------
# Accuracy for Decision Tree: 0.7630
# Classification Report for Decision Tree:
#                precision    recall  f1-score   support
#
#            0       0.88      0.83      0.86       324
#            1       0.30      0.38      0.34        60
#
#     accuracy                           0.76       384
#    macro avg       0.59      0.61      0.60       384
# weighted avg       0.79      0.76      0.77       384
#
# --------------------------------------------------
# Accuracy for SVM: 0.8438
# Classification Report for SVM:
#                precision    recall  f1-score   support
#
#            0       0.84      1.00      0.92       324
#            1       0.00      0.00      0.00        60
#
#     accuracy                           0.84       384
#    macro avg       0.42      0.50      0.46       384
# weighted avg       0.71      0.84      0.77       384
#
# --------------------------------------------------
# Accuracy for Logistic Regression: 0.8385
# Classification Report for Logistic Regression:
#                precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91       324
#            1       0.33      0.03      0.06        60
#
#     accuracy                           0.84       384
#    macro avg       0.59      0.51      0.49       384
# weighted avg       0.77      0.84      0.78       384
#
# --------------------------------------------------
# Accuracy for Naive Bayes: 0.8099
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report for Naive Bayes:
#                precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89       324
#            1       0.38      0.33      0.35        60
#
#     accuracy                           0.81       384
#    macro avg       0.63      0.62      0.62       384
# weighted avg       0.80      0.81      0.81       384
#
# --------------------------------------------------
#
#
# Testing for imbalance level: 300 samples
# --------------------------------------------------
# Skipping strategy 'not majority' as it results in one class
#
#
# Testing for imbalance level: 300 samples
# --------------------------------------------------
# Accuracy for Decision Tree: 0.7708
# Classification Report for Decision Tree:
#                precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86       324
#            1       0.32      0.40      0.35        60
#
#     accuracy                           0.77       384
#    macro avg       0.60      0.62      0.61       384
# weighted avg       0.79      0.77      0.78       384
#
# --------------------------------------------------
# Accuracy for SVM: 0.8438
# Classification Report for SVM:
#                precision    recall  f1-score   support
#
#            0       0.84      1.00      0.92       324
#            1       0.00      0.00      0.00        60
#
#     accuracy                           0.84       384
#    macro avg       0.42      0.50      0.46       384
# weighted avg       0.71      0.84      0.77       384
#
# --------------------------------------------------
# Accuracy for Logistic Regression: 0.8385
# Classification Report for Logistic Regression:
#                precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91       324
#            1       0.33      0.03      0.06        60
#
#     accuracy                           0.84       384
#    macro avg       0.59      0.51      0.49       384
# weighted avg       0.77      0.84      0.78       384
#
# --------------------------------------------------
# Accuracy for Naive Bayes: 0.8099
# Classification Report for Naive Bayes:
#                precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89       324
#            1       0.38      0.33      0.35        60
#
#     accuracy                           0.81       384
#    macro avg       0.63      0.62      0.62       384
# weighted avg       0.80      0.81      0.81       384
#
# --------------------------------------------------
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/studentx/RCS_M1/pyenv_imbalance/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
